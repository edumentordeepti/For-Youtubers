# %%
import pandas as pd
import numpy as np

# %%
"""the groupby().transform() method is used to perform group-specific computations
and return a result that has the same shape as the original DataFrame or Series"""

"""This differs from groupby().apply() which can return an aggregated result,
potentially changing the shape of the data."""
data = pd.read_csv('myntra_dataset_ByScraping.csv')
data.head(10)
# Out:
#        brand_name              pants_description   price     MRP  \
# 0           WROGN     Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1  Flying Machine             Men Slim Fit Jeans  1829.0  2999.0
# 2        Roadster          Men Pure Cotton Jeans   974.0  2499.0
# 3      Bene Kleed        Relaxed Fit Denim Jeans   873.0  2299.0
# 4           Levis         Men 511 Slim Fit Jeans  1478.0  2899.0
# 5        HERE&NOW          Men Stretchable Jeans   798.0  1699.0
# 6  Urbano Fashion          Men Relaxed Fit Jeans   944.0  2099.0
# 7           WROGN             Men Anti Fit Jeans  1623.0  2799.0
# 8      Bene Kleed  Men Wide Leg Heavy Fade Jeans   839.0  2799.0
# 9      Bene Kleed        Relaxed Fit Denim Jeans   873.0  2299.0
#
#    discount_percent  ratings  number_of_ratings
# 0              0.45      4.2               57.0
# 1              0.39      4.6                5.0
# 2              0.61      3.6             1100.0
# 3              0.62      4.0             4800.0
# 4              0.49      4.3              264.0
# 5              0.53      4.0               33.0
# 6              0.55      4.0             4200.0
# 7              0.42      4.2               42.0
# 8              0.70      3.6              114.0
# 9              0.62      4.1             5200.0

# %% [markdown]
# ###Common Use Cases:
# 1) Filling missing values within groups using group-specific statistics (e.g., group mean).
# 2) Normalizing or standardizing data within groups.
# 3) Creating new features based on group-level information.

# %%
grouped = data.groupby('brand_name')
grouped.head()
# Out:
#            brand_name           pants_description   price     MRP  \
# 0               WROGN  Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1      Flying Machine          Men Slim Fit Jeans  1829.0  2999.0
# 2            Roadster       Men Pure Cotton Jeans   974.0  2499.0
# 3          Bene Kleed     Relaxed Fit Denim Jeans   873.0  2299.0
# 4               Levis      Men 511 Slim Fit Jeans  1478.0  2899.0
# ...               ...                         ...     ...     ...
# 51432     ARBIA FUNKI          Men Mid Rise Jeans  1393.0  3399.0
# 51534   M&H Our Water  Men Slim Tapered Fit Jeans   643.0  2299.0
# 51584   M&H Our Water  Men Slim Tapered Fit Jeans   643.0  2299.0
# 51855       RUF & TUF        Men Skinny Fit Jeans  1829.0  2999.0
# 51965        Ed Hardy          Men Slim Fit Jeans  1275.0  2199.0
#
#        discount_percent  ratings  number_of_ratings
# 0                  0.45      4.2               57.0
# 1                  0.39      4.6                5.0
# 2                  0.61      3.6             1100.0
# 3                  0.62      4.0             4800.0
# 4                  0.49      4.3              264.0
# ...                 ...      ...                ...
# 51432              0.59      3.8               22.0
# 51534              0.72      4.1              183.0
# 51584              0.72      4.1              183.0
# 51855              0.39      4.6                5.0
# 51965              0.42      4.2              130.0
#
# [1788 rows x 7 columns]

# %%
data['brand_name'].nunique()
# Out:
# 417

# %%
data['price_Mean'] = grouped['price'].transform('mean')
data['price_Mean'].head(20)
# Out:
# 0     1410.673770
# 1     1813.166442
# 2      779.847005
# 3     1004.176829
# 4     1946.544821
# 5     1205.267552
# 6     1033.402878
# 7     1410.673770
# 8     1004.176829
# 9     1004.176829
# 10     779.847005
# 11    1004.176829
# 12    1004.176829
# 13    1813.166442
# 14    1402.220779
# 15     779.847005
# 16    2781.264931
# 17    1402.220779
# 18    1004.176829
# 19    1410.673770
# Name: price_Mean, dtype: float64

# %%
data['price_Mean'].shape
# Out:
# (52120,)

# %%
data.shape
# Out:
# (52120, 8)

# %%
data.head()
# Out:
#        brand_name           pants_description   price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1  Flying Machine          Men Slim Fit Jeans  1829.0  2999.0
# 2        Roadster       Men Pure Cotton Jeans   974.0  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans   873.0  2299.0
# 4           Levis      Men 511 Slim Fit Jeans  1478.0  2899.0
#
#    discount_percent  ratings  number_of_ratings   price_Mean
# 0              0.45      4.2               57.0  1410.673770
# 1              0.39      4.6                5.0  1813.166442
# 2              0.61      3.6             1100.0   779.847005
# 3              0.62      4.0             4800.0  1004.176829
# 4              0.49      4.3              264.0  1946.544821

# %%
data['ratings'].nunique()
# Out:
# 41

# %%
"""The groupby().apply() combination in Pandas allows for flexible, custom operations on grouped data,
 where a function is applied to each group as a DataFrame or Series."""

 # Define a custom function to apply to each group
def calculate_custom_metric(group):
    """
    Calculates a custom metric for each group: (sum of Value1) / (max of Value2)
    """
    sum_value1 = group['number_of_ratings'].sum()
    max_value2 = group['ratings'].max()
    if max_value2 == 0:  # Avoid division by zero
        return 0
    return sum_value1 / max_value2

# Group by 'Category' and apply the custom function
result = data.groupby('price').apply(calculate_custom_metric)
result.head(20)
# Out:
# /tmp/ipython-input-937399930.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = data.groupby('price').apply(calculate_custom_metric)
# price
# 337.0      65.714286
# 359.0      68.372093
# 369.0      86.500000
# 376.0     114.186047
# 377.0    1377.608696
# 378.0    1481.458333
# 379.0    2702.608696
# 380.0    2692.608696
# 389.0      67.826087
# 397.0       5.806452
# 399.0     711.555556
# 402.0     129.285714
# 404.0       5.000000
# 413.0     222.000000
# 415.0     255.434783
# 417.0     737.659574
# 418.0    3980.217391
# 419.0    3482.127660
# 420.0    3556.304348
# 428.0     565.813953
# dtype: float64

# %%
result.shape
# Out:
# (1485,)

# %%
"""You can create a Pandas Series or DataFrame column with the category dtype."""
# Convert 'brand_name' column to categorical
data['brand_name'] = data['brand_name'].astype('category')
data['brand_name'].dtype
# Out:
# CategoricalDtype(categories=['7 For All Mankind', '7OUNCE', 'AD By Arvind', 'ADBUCKS',
#                   'ADIDAS Originals', 'AFLASH', 'ALCOTT',
#                   'ALTINYILDIZ CLASSICS AC Co.', 'ALTIVA',
#                   'AMERICAN EAGLE OUTFITTERS',
#                   ...
#                   'ether', 'fineblu', 'glitchez', 'max', 'me Queen',
#                   'mode de base', 'nostrum', 'prochain', 'styzon',
#                   'the Misnomer'],
# , ordered=False, categories_dtype=object)

# %%
print("\nCategories of brand_name", data['brand_name'].cat.categories)
# Out:
# Categories of brand_name Index(['7 For All Mankind', '7OUNCE', 'AD By Arvind', 'ADBUCKS',
#        'ADIDAS Originals', 'AFLASH', 'ALCOTT', 'ALTINYILDIZ CLASSICS AC Co.',
#        'ALTIVA', 'AMERICAN EAGLE OUTFITTERS',
#        ...
#        'ether', 'fineblu', 'glitchez', 'max', 'me Queen', 'mode de base',
#        'nostrum', 'prochain', 'styzon', 'the Misnomer'],
#       dtype='object', length=417)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52120 entries, 0 to 52119
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         52120 non-null  category
#  1   pants_description  52120 non-null  object
#  2   price              52120 non-null  float64
#  3   MRP                52120 non-null  float64
#  4   discount_percent   52120 non-null  float64
#  5   ratings            52120 non-null  float64
#  6   number_of_ratings  52120 non-null  float64
#  7   price_Mean         52120 non-null  float64
# dtypes: category(1), float64(6), object(1)
# memory usage: 2.9+ MB

# %%
new_brand = data['brand_name'].cat.add_categories("Fashor")
new_brand[52120] = 'Fashor'
new_brand.tail()
# Out:
# 52116      HERE&NOW
# 52117    Pepe Jeans
# 52118         Celio
# 52119    Pepe Jeans
# 52120        Fashor
# Name: brand_name, dtype: category
# Categories (418, object): ['7 For All Mankind', '7OUNCE', 'AD By Arvind', 'ADBUCKS', ..., 'prochain', 'styzon',
#                            'the Misnomer', 'Fashor']

# %%
data['brand_name'].cat.categories
# Out:
# Index(['7 For All Mankind', '7OUNCE', 'AD By Arvind', 'ADBUCKS',
#        'ADIDAS Originals', 'AFLASH', 'ALCOTT', 'ALTINYILDIZ CLASSICS AC Co.',
#        'ALTIVA', 'AMERICAN EAGLE OUTFITTERS',
#        ...
#        'ether', 'fineblu', 'glitchez', 'max', 'me Queen', 'mode de base',
#        'nostrum', 'prochain', 'styzon', 'the Misnomer'],
#       dtype='object', length=417)

# %%
renamed_brand = new_brand.cat.rename_categories({'Fashor':'Aurelia'})
renamed_brand.tail()
# Out:
# 52116      HERE&NOW
# 52117    Pepe Jeans
# 52118         Celio
# 52119    Pepe Jeans
# 52120       Aurelia
# Name: brand_name, dtype: category
# Categories (418, object): ['7 For All Mankind', '7OUNCE', 'AD By Arvind', 'ADBUCKS', ..., 'prochain', 'styzon',
#                            'the Misnomer', 'Aurelia']

# %%
new_brand.shape
# Out:
# (52121,)

# %%
brands = new_brand.cat.remove_unused_categories()
brands.tail()
# Out:
# 52116      HERE&NOW
# 52117    Pepe Jeans
# 52118         Celio
# 52119    Pepe Jeans
# 52120        Fashor
# Name: brand_name, dtype: category
# Categories (418, object): ['7 For All Mankind', '7OUNCE', 'AD By Arvind', 'ADBUCKS', ..., 'prochain', 'styzon',
#                            'the Misnomer', 'Fashor']

# %%
brands.shape
# Out:
# (52121,)
